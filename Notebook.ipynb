# %%
import pandas as pd
import os

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

from drawer import PlotsDrawer

# %%
drawer = PlotsDrawer()
paths = drawer.draw_plots(r"data/data.json", "first_label", "second_label", "plots")

# %%
# display plots created by PlotsDrawer
for path in paths:
    plt.figure(figsize = (10, 10))
    img = mpimg.imread(path)
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()
